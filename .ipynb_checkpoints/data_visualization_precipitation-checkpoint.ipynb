# %%
from data_processor import *
from global_variables import *
import matplotlib.pyplot as plt
if not os.path.exists('pics/'):
    os.makedirs('pics/')

# %% [markdown]
# ### A City's Monthly Average Precipitation of a Whole Year

# %%
# Parameter
city = 'KSAN'
year = 2018
fname = 'pics/{}_precip_y{}_plot.jpg'.format(city,year)
# Code
monthly_avg_precip_list = []
for month in range(1,13):
    month_start, month_end = get_monthly_start_end(year=year, month=month)
    weather_info = get_info(city,month_start, month_end, info_type='precipitation', output=False)
    monthly_avg_precip_list.append(weather_info['mean'])
print(monthly_avg_precip_list)
year_start, year_end = get_yearly_start_end(year=year)
weather_info = get_info(city,year_start, year_end, info_type='precipitation', output=False)
yearly_avg_precip_list = list([weather_info['mean'] for i in range(12)])
print(yearly_avg_precip_list)
# Out:
# [0.057096774193548396, 0.012500000000000015, 0.020967741935483893, 0.0006666666666666666, 0.0029032258064516383, 9.999999999999999e-18, 0.0, 0.0006451612903225806, 3.3333333333333333e-18, 0.01838709677419356, 0.023000000000000003, 0.026774193548387098]
# [0.013671232876712337, 0.013671232876712337, 0.013671232876712337, 0.013671232876712337, 0.013671232876712337, 0.013671232876712337, 0.013671232876712337, 0.013671232876712337, 0.013671232876712337, 0.013671232876712337, 0.013671232876712337, 0.013671232876712337]

# %%
# Plot
plt.figure(figsize=(20,10))
plt.plot(range(12), monthly_avg_precip_list)
plt.plot(range(12), yearly_avg_precip_list, '--')
title_str = '{}\'s Monthly Precipitation Situation in Year {}'.format(code_city_refer[city], year)
plt.xlabel('Month')
plt.xticks(range(12),['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'])
plt.ylabel('Precipitation (mm)')
plt.title(title_str,fontsize='xx-large',fontweight='bold')
plt.legend(['Monthly Average Precipitation','Yearly Average Precipitation'])
plt.grid()
plt.show()

# %% [markdown]
# ### A City's Average Preicipitation of a Specific Month in All Years (1990 - 2019)

# %%
# Parameter
city = 'KSAN'
month = 3
fname = 'pics/{}_precip_allyears_plot.jpg'.format(city)
# Code
start_year = 1990
end_year = 2019
if month > 4:
    end_year = 2018
monthly_avg_precip_list = []
yearly_avg_precip_list = []
for year in range(start_year, end_year + 1):
    month_start, month_end = get_monthly_start_end(year=year, month=month)
    weather_info = get_info(city,month_start, month_end, info_type='precipitation', output=False)
    monthly_avg_precip_list.append(weather_info['mean'])
    year_start, year_end = get_yearly_start_end(year=year)
    weather_info = get_info(city,year_start, year_end, info_type='precipitation', output=False)
    yearly_avg_precip_list.append(weather_info['mean'])
print(monthly_avg_precip_list)
# Out:
# [2.306774193548387, 2.509032258064517, 1.7796774193548388, 0.24903225806451615, 0.13516129032258062, 0.32774193548387104, 0.2812903225806451, 0.0, 0.07129032258064516, 0.035483870967741936, 0.034193548387096775, 0.02032258064516129, 0.014838709677419354, 0.04225806451612903, 0.012903225806451613, 0.06483870967741935, 0.043870967741935496, 0.0029032258064516257, 0.00838709677419356, 0.00580645161290323, 0.021935483870967755, 0.04483870967741937, 0.020967741935483886, 0.027096774193548393, 0.027096774193548393, 0.02870967741935484, 0.010322580645161297, 0.0025806451612903226, 0.020967741935483893, 0.03935483870967744]

# %%
# plot
plt.figure(figsize=(20,10))
plt.plot(range(start_year, end_year), monthly_avg_precip_list[:-1])
plt.plot(range(start_year, end_year), yearly_avg_precip_list[:-1], '--')
title_str = '{}\'s Monthly Precipitation Situation of Month {} in All years'.format(code_city_refer[city], month)
plt.xlabel('Year')
plt.ylabel('Precipitation')
plt.title(title_str,fontsize='xx-large',fontweight='bold')
plt.legend(['Monthly Average Precipitation','Yearly Average Precipitation'])
plt.grid()
plt.show()

# %% [markdown]
#  ### A City's Yearly Average Temperature in All Years (1990 - 2018)

# %%
# Parameter
city = 'KSAN'
fname = 'pics/{}_precip_allyears_plot.jpg'.format(city)
# Code
start_year = 1990
end_year = 2019
yearly_all_precip_list = []
for year in range(start_year, end_year + 1):
    year_start, year_end = get_yearly_start_end(year=year)
    weather_info = get_info(city,year_start, year_end, info_type='precipitation', output=False)
    yearly_all_precip_list.append(weather_info['mean']*weather_info['count'])
print(yearly_all_precip_list)
# Out:
# [733.7699999999999, 1234.8100000000002, 900.5800000000002, 481.03000000000003, 20.12, 101.82, 51.10000000000001, 6.970000000000001, 16.09, 5.440000000000001, 6.19, 8.340000000000002, 3.9300000000000006, 8.94, 13.009999999999998, 13.460000000000003, 6.1300000000000034, 4.570000000000002, 11.110000000000003, 5.490000000000002, 15.570000000000002, 6.310000000000002, 4.920000000000003, 3.260000000000001, 6.3900000000000015, 6.240000000000003, 9.260000000000003, 5.6300000000000034, 4.990000000000003, 5.920000000000002]

# %%
# plot
plt.figure(figsize=(20,10))
plt.plot(range(start_year, end_year), yearly_all_precip_list[:-1])
title_str = '{}\'s Yearly Total Precipitation Situation in All years'.format(code_city_refer[city])
plt.xlabel('Year')
plt.ylabel('Precipitation (mm)')
plt.title(title_str,fontsize='xx-large',fontweight='bold')
plt.grid()
plt.show()

# %% [markdown]
# ### City's Yearly Total Precipitation Comparison (1990 - 2018)

# %%
# Parameter
fname = 'pics/{}_temp_allyears_plot.jpg'.format(city)
# Code
start_year = 1995
end_year = 2018
cities_yearly_precip_dict = dict([(city,[]) for city in city_code_refer.values()])
for city in city_code_refer.values():
    for year in range(start_year, end_year + 1):
        year_start, year_end = get_yearly_start_end(year=year)
        weather_info = get_info(city,year_start, year_end, info_type='precipitation', output=False)
        cities_yearly_precip_dict[city].append(weather_info['mean'] * weather_info['count'])
print(cities_yearly_precip_dict)
# Out:
# {'KSEA': [103.36000000000001, 73.37, 41.64, 40.97, 40.74000000000001, 24.91, 36.95, 31.23, 41.11, 30.610000000000003, 35.27, 48.43, 38.96000000000001, 30.73, 38.43000000000001, 46.99000000000001, 36.400000000000006, 48.260000000000005, 32.56, 48.480000000000004, 44.83, 45.14000000000001, 47.29000000000001, 35.730000000000004], 'KSFO': [103.03, 65.08, 20.32, 32.339999999999996, 15.080000000000002, 18.23, 26.159999999999997, 19.479999999999997, 18.63, 19.0, 26.92, 20.85, 11.530000000000001, 15.06, 16.450000000000003, 23.76, 16.59, 21.47, 3.4000000000000026, 20.700000000000003, 8.330000000000002, 20.8, 24.22, 15.690000000000003], 'KBUR': [0.0, 0.0, 0.38, 2.1, 7.13, 10.73, 16.43, 0.10000000000000002, 13.200000000000001, 16.9, 25.470000000000002, 11.999999999999998, 4.440000000000001, 14.59, 9.940000000000001, 22.240000000000002, 12.450000000000001, 8.280000000000001, 1.7400000000000022, 6.810000000000001, 5.560000000000002, 9.450000000000003, 8.350000000000001, 10.24], 'KSAN': [101.82, 51.10000000000001, 6.970000000000001, 16.09, 5.440000000000001, 6.19, 8.340000000000002, 3.9300000000000006, 8.94, 13.009999999999998, 13.460000000000003, 6.1300000000000034, 4.570000000000002, 11.110000000000003, 5.490000000000002, 15.570000000000002, 6.310000000000002, 4.920000000000003, 3.260000000000001, 6.3900000000000015, 6.240000000000003, 9.260000000000003, 5.6300000000000034, 4.990000000000003], 'KHOU': [114.84, 72.89999999999999, 96.78, 153.59999999999997, 30.979999999999997, 40.04, 78.09, 58.23000000000001, 43.92, 55.790000000000006, 35.620000000000005, 52.73, 64.05000000000001, 45.540000000000006, 47.03, 40.17, 23.810000000000002, 42.33, 38.67, 44.220000000000006, 66.59, 60.81, 55.940000000000005, 55.019999999999996], 'KBOS': [147.37, 96.36000000000001, 29.17, 52.21000000000001, 37.120000000000005, 36.17, 29.48, 39.93, 40.72, 44.06999999999999, 40.7, 52.470000000000006, 38.970000000000006, 54.480000000000004, 43.34, 49.06000000000001, 50.34, 35.980000000000004, 38.230000000000004, 44.45, 34.75, 32.650000000000006, 41.82000000000001, 52.03], 'KLGA': [143.01, 102.9, 42.69, 43.72, 39.71, 34.04, 32.55, 42.28, 51.46, 49.46000000000001, 46.230000000000004, 53.34, 52.960000000000015, 47.82000000000001, 46.120000000000005, 40.52, 65.24000000000001, 36.11, 38.82000000000001, 50.17, 36.93000000000001, 39.39, 42.2, 58.88999999999999], 'KDCA': [143.59, 102.74, 32.11, 35.59, 38.92, 33.879999999999995, 29.939999999999998, 33.290000000000006, 59.0, 40.870000000000005, 43.95, 47.51, 32.790000000000006, 45.34, 45.99000000000001, 33.99000000000001, 46.89000000000001, 32.46000000000001, 44.28, 44.690000000000005, 44.89, 31.69, 35.540000000000006, 66.28]}

# %%
# plot
plt.figure(figsize=(20,10))
for city in city_code_refer.values():
    plt.plot(range(start_year, end_year+1), cities_yearly_precip_dict[city])
title_str = 'All Cities\'s Yearly Precipitation Situation in All years'
plt.xlabel('Year')
plt.ylabel('Precipitation (mm)')
plt.title(title_str,fontsize='xx-large',fontweight='bold')
plt.legend(list(city_code_refer.keys()))
plt.grid()
plt.show()
